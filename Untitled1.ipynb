# %% [markdown]
# <a href="https://colab.research.google.com/github/faalalsakakir-26/README/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import lipraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
td = pd.read_csv('/content/StudentsPerformance.csv')#this function

# %%
td.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
td = pd.get_dummies(td, columns=['race/ethnicity'], prefix='race')
display(td.head())
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  race_group A  race_group B  \
# 0          72             72             74         False          True
# 1          69             90             88         False         False
# 2          90             95             93         False          True
# 3          47             57             44          True         False
# 4          76             78             75         False         False
#
#    race_group C  race_group D  race_group E
# ...

# %%
sns.heatmap(td.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
td.drop((['parental level of education','lunch','test preparation course']),axis=1,inplace=True)

# %%
td.head()
# Out:
#    gender  math score  reading score  writing score  race_group A  \
# 0  female          72             72             74         False
# 1  female          69             90             88         False
# 2  female          90             95             93         False
# 3    male          47             57             44          True
# 4    male          76             78             75         False
#
#    race_group B  race_group C  race_group D  race_group E
# 0          True         False         False         False
# 1         False          True         False         False
# 2          True         False         False         False
# 3         False         False         False         False
# 4         False          True         False         False

# %%
gendar=pd.get_dummies(td['gender'],drop_first=True)

# %%
td.head()
# Out:
#    gender  math score  reading score  writing score  race_group A  \
# 0  female          72             72             74         False
# 1  female          69             90             88         False
# 2  female          90             95             93         False
# 3    male          47             57             44          True
# 4    male          76             78             75         False
#
#    race_group B  race_group C  race_group D  race_group E
# 0          True         False         False         False
# 1         False          True         False         False
# 2          True         False         False         False
# 3         False         False         False         False
# 4         False          True         False         False

# %%
td.drop(['gender'],axis=1,inplace=True)

# %%
td.head()
# Out:
#    math score  reading score  writing score  race_group A  race_group B  \
# 0          72             72             74         False          True
# 1          69             90             88         False         False
# 2          90             95             93         False          True
# 3          47             57             44          True         False
# 4          76             78             75         False         False
#
#    race_group C  race_group D  race_group E
# 0         False         False         False
# 1          True         False         False
# 2         False         False         False
# 3         False         False         False
# 4          True         False         False

# %%
td['race_group_AB'] = td['race_group B'] | td['race_group A']
td['race_group_CD'] = td['race_group C'] | td['race_group D']
# race_group E is already separate

display(td.head())
# Out:
#    math score  reading score  writing score  race_group A  race_group B  \
# 0          72             72             74         False          True
# 1          69             90             88         False         False
# 2          90             95             93         False          True
# 3          47             57             44          True         False
# 4          76             78             75         False         False
#
#    race_group C  race_group D  race_group E  race_group_AB  race_group_CD
# 0         False         False         False           True          False
# 1          True         False         False          False           True
# 2         False         False         False           True          False
# 3         False         False         False           True          False
# 4          True         False         False          False           True

# %%
td.drop(['race_group B','race_group C','race_group D','race_group A'],axis=1,inplace=True)

# %%
td.head()
# Out:
#    math score  reading score  writing score  race_group E  race_group_AB  \
# 0          72             72             74         False           True
# 1          69             90             88         False          False
# 2          90             95             93         False           True
# 3          47             57             44         False           True
# 4          76             78             75         False          False
#
#    race_group_CD
# 0          False
# 1           True
# 2          False
# 3          False
# 4           True
